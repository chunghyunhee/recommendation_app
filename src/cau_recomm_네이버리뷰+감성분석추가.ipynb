# %%
import pandas as pd
import numpy as np

df = pd.read_csv('https://github.com/TaewoongKong/code_sharing/blob/master/cau_shops_kakao_edit.csv?raw=True')
#df = pd.read_csv('cau_shops_kakao_edit.csv')

# %%
# 필요 칼럼만 이용

df_recom = df[['카카오지도_상호명',
               '상권업종중분류명',
               '상권업종소분류명',
               '카카오지도_카테고리',
               '경도',
               '위도',
               '카카오지도_별점_점수',
               '카카오지도_별점_평가수',
               '카카오지도_블로그_리뷰',
               '카카오지도_블로그_리뷰수']]

# %%
# 칼럼명 단순화

df_recom.columns = ['name',  # 상호명
                    'cate_1',  
                    'cate_2', 
                    'cate_3',
                    'lon',
                    'lat',
                    'star_point',  # 별점 점수
                    'star_qty',  # 별점 평가 횟수
                    'review_txt',  # 리뷰 텍스트
                    'review_qty'  #  리뷰 횟수 - 유명할수록 많은데 부정적인 평가도 있을 수 있다
                   ]

# %%
# 별점 평가 개수가 0개면 별점을 -1 로 Null 처리

df_recom.loc[df_recom['star_qty'] == 0, 'star_point'] = -1



# 각종 카테고리를 통합
df_recom['cate_mix'] = df_recom['cate_1'] + df_recom['cate_2'] + df_recom['cate_3']
df_recom['cate_mix'] = df_recom['cate_mix'].str.replace(">", " ").str.replace("/", " ")
# Out:
# C:\Users\jungh\anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# C:\Users\jungh\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\jungh\anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity


# 리뷰의 유사도 학습


count_vect_review = CountVectorizer(min_df=2, ngram_range=(1,2))
place_review = count_vect_review.fit_transform(df_recom['review_txt']) 
place_simi_review = cosine_similarity(place_review, place_review)
place_simi_review_sorted_ind = place_simi_review.argsort()[:, ::-1]


# 카테고리의 유사도 학습

count_vect_category = CountVectorizer(min_df=0, ngram_range=(1,2))
place_category = count_vect_category.fit_transform(df_recom['cate_mix']) 
place_simi_cate = cosine_similarity(place_category, place_category) 
place_simi_cate_sorted_ind = place_simi_cate.argsort()[:, ::-1] 


# 카테고리와 리뷰의 중요성을 짬뽕시키는 공식
place_simi_co = (place_simi_review*0.2  # 리뷰 유사도는 0.1만큼 반영
                 + place_simi_cate*0.05 
                 + np.repeat([df_recom['star_qty'].values], len(df_recom['star_qty']) , axis=0) * 0.001  # 별점평가 갯수
                 + np.repeat([df_recom['star_point'].values], len(df_recom['star_point']) , axis=0) * 0.001 # 별점 평가 반영
                )


# 필요한 작업
place_simi_co_sorted_ind = place_simi_co.argsort()[:, ::-1]

# %%
# 위경도 구하는 공식 

def haversine_distance(lat1, lon1, lat2, lon2):
    r = 6371
    phi1 = np.radians(lat1)
    phi2 = np.radians(lat2)
    delta_phi = np.radians(lat2 - lat1)
    delta_lambda = np.radians(lon2 - lon1)
    a = np.sin(delta_phi / 2)**2 + np.cos(phi1) * np.cos(phi2) *   np.sin(delta_lambda / 2)**2
    res = r * (2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a)))
    return np.round(res, 2)



# 추천엔진 돌리는 최종 함수

def find_simi_place(df, sorted_ind, place_name, top_n=10):
    
    
    
    place_title = df[df['name'] == place_name]
    place_index = place_title.index.values
    similar_indexes = sorted_ind[place_index, :(top_n)]
    similar_indexes = similar_indexes.reshape(-1)
    result_df = df.iloc[similar_indexes]
    
    start_lat, start_lon = result_df['lat'].tolist()[0], result_df['lon'].tolist()[0]
    
    distances_km = []
    for row in result_df.itertuples(index=False):
        distances_km.append(haversine_distance(start_lat, start_lon, row.lat, row.lon))
    
    
    result_df['distance'] = distances_km
    
    

    return result_df.sort_values(by='distance')  # 위경도 거리를 가까운 순으로 점수 올려서 순서를 바꿔줘도 되고... (sorting 이용)

# %%
find_simi_place(df_recom,place_simi_co_sorted_ind, "BHC치킨 중앙대점", 7)
# Out:
# C:\Users\jungh\anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            name  cate_1     cate_2            cate_3         lon        lat  \
# 25   BHC치킨 중앙대점  닭/오리요리  후라이드/양념치킨  음식점 > 치킨 > BHC치킨  126.958410  37.507019
# 89         치폴레옹  닭/오리요리  후라이드/양념치킨          음식점 > 치킨  126.960671  37.507967
# 110   우뇽뚝배기스파게티      양식    스파게티전문점   음식점 > 양식 > 이탈리안  126.961633  37.506300
# 175    호치킨 중앙대점  닭/오리요리  후라이드/양념치킨    음식점 > 치킨 > 호치킨  126.962672  37.508012
# 9    교촌치킨 상도터널점  닭/오리요리  후라이드/양념치킨   음식점 > 치킨 > 교촌치킨  126.951280  37.504911
# 172         사리원      분식  국수/만두/칼국수     음식점 > 한식 > 냉면  126.950615  37.499147
# 293  BHC치킨 숭실대점  닭/오리요리  후라이드/양념치킨  음식점 > 치킨 > BHC치킨  126.957436  37.494928
#
#      star_point  star_qty                                         review_txt  \
# 25          4.0         2  안녕하세요~! 부동산 발자국입니다. 치킨이 땡기는 날이라 치킨을 먹었습니다. 흑서동...
# 89          4.2        10  성인이 된 이후 이사온 흑석동 처음엔 쭉 자라온 동네를 떠나오는게 너무 싫고 동네친...
# 110         3.7        69  중앙대병원에 서류를 좀 발급받으러 갔다.. 아따 비싸네...... 근데 물어보니 무...
# 175         3.1        10  퇴근길에 치킨이 땡겨서 치킨을 포장해왔는데요~ 오늘은 외근으로 중앙대병원 근처 왔다...
# 9           1.8        23  교촌치킨 동작구 상도터널점 메뉴 및 영업시간 ＊누구나 즐기는 간식거리 치킨!! 그중...
# 172         3.1       111  안녕하세요 공공일이에요! 저는 티엠아이지만. 저희 할아버지께서 이북에서 오셔서 이북...
# 293         3.1        11  종강까지의 일상 드디어 내가 종강을 하긴 하는구나 어찌됐든 이번 학기도 잘 버텼다 ...
#
#      review_qty                         cate_mix  distance
# 25            5  닭 오리요리후라이드 양념치킨음식점   치킨   BHC치킨      0.00
# 89           22          닭 오리요리후라이드 양념치킨음식점   치킨      0.23
# 110          40         양식스파게티전문점음식점   양식   이탈리안      0.30
# 175          29    닭 오리요리후라이드 양념치킨음식점   치킨   호치킨      0.39
# 9             2   닭 오리요리후라이드 양념치킨음식점   치킨   교촌치킨      0.67
# 172          42         분식국수 만두 칼국수음식점   한식   냉면      1.11
# 293          10  닭 오리요리후라이드 양념치킨음식점   치킨   BHC치킨      1.35

# %%
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
# 네이버 블로그 리뷰와 별점 평가가 필요한 항목들을 아래 코드를 돌리면 1과 Null로 구분되게 짜두었습니다
# 1로 표기된 상호들만 크롤링 해주시면 됩니다
# 데이터의 수는 21개 뿐입니다 (인간지능 해도 될듯...?)

df_recom['naver_blog_need'] = np.nan


df_recom.loc[(df_recom['review_txt'] == 'empty')
             & (df_recom['star_qty'] == 0)].index.tolist()

df_recom.loc[df_recom.index.isin(df_recom.loc[(df_recom['review_txt'] == 'empty') & (df_recom['star_qty'] == 0)].index.tolist()), 'naver_blog_need'] = 1

# %%
df_recom.head()
# Out:
#            name  cate_1       cate_2              cate_3         lon  \
# 0            블룸      양식     정통양식/경양식  음식점 > 술집 > 호프,요리주점  126.960370
# 1  쉬어가는 모퉁이커피한잔  커피점/카페  커피전문점/카페/다방    음식점 > 카페 > 커피전문점  126.953412
# 2          손칼국수      분식    국수/만두/칼국수       음식점 > 한식 > 국수  126.957832
# 3      김가네 중앙대점      분식       라면김밥분식      음식점 > 분식 > 김가네  126.964406
# 4    중앙대학교 학생식당   기타음식업  구내식당/자급식음식점          음식점 > 구내식당  126.953838
#
#          lat  star_point  star_qty  \
# 0  37.507649         4.0         1
# 1  37.497226         4.5         5
# 2  37.494958         4.1        20
# 3  37.507802         1.0         2
# 4  37.504798        -1.0         0
#
#                                           review_txt  review_qty  \
# 0  블룸 또 갔다믄써~~~ 중대앞에서 칵테일 마시고 싶다면 여기가 ㄱㅊ은듯?? 새벽 1...           2
# 1                                              empty           0
# 2  사실 후기랄 것이 없다. 자주 가는 곳이고 늘 같은 메뉴. 숭실대 중문 쪽에 아주 ...          28
# 3  강식당 보다가 피오가 만든 김치밥 너무 먹구시픈데 집에 김치가 없는 슬픈 자취생이라...           6
# 4  중앙대생 점심 메뉴를 추천해드리려고해요 아마 재학생들은 다 알고 있을 310관 지하...           1
#
#                             cate_mix  naver_blog_need
# 0       양식정통양식 경양식음식점   술집   호프,요리주점              NaN
# 1  커피점 카페커피전문점 카페 다방음식점   카페   커피전문점              NaN
# 2           분식국수 만두 칼국수음식점   한식   국수              NaN
# 3             분식라면김밥분식음식점   분식   김가네              NaN
# 4         기타음식업구내식당 자급식음식점음식점   구내식당              NaN

# %%
# naver_blog 크롤링이 필요한 부분
review_empty = []

for i in range(len(df_recom)):
    if df_recom['naver_blog_need'][i] == 1:
        review_empty.append(df_recom['name'][i])

# %%
len(review_empty)
# Out:
# 21

# %%
# 크롤링 데이터로 채우기 (리뷰, 평점)
naver_review = pd.read_csv('review_naver.csv')

# %%
naver_review.head()
# Out:
#      name  star_point  star_qty  \
# 0    종로떡집        4.18      37.0
# 1  윤정즉석김밥        4.57       7.0
# 2   현주네김밥        5.00       2.0
# 3   JM호프바        4.75       2.0
# 4  모코커피창고        4.44      25.0
#
#                                           review_txt  review_qty
# 0  우리쌀을 사용하여 떡을 만들어서 맛있어요~ 상점이 깨끗해요 오후 5시이후에는 세일해...         5.0
# 1                                              empty         0.0
# 2                                              empty         0.0
# 3                                       분위기 좋고 괜찮음 ㅎ         1.0
# 4  아이스아메리카노 맛있어요~ 직접 로스팅하는 곳이라 인정!!!아이스아메리카노 마셨는데...        13.0

# %%
# 원래 데이터에서 naver_blog_need부분자체를 그대로 넣어버리기 
for i in range(len(df_recom)):
    for j in range(len(naver_review)):
        if df_recom['name'][i] == naver_review['name'][j]:
            df_recom['star_point'][i] = naver_review['star_point'][j]
            df_recom['star_qty'][i] = naver_review['star_qty'][j]
            df_recom['review_txt'][i] = naver_review['review_txt'][j]
            df_recom['review_qty'][i] = naver_review['review_qty'][j]

# %%
# 저장
df_recom.to_csv('new_df_recom.csv', index = False)

# %%
# 만약 review_txt가 비어있으면 삭제
for i in range(len(df_recom)):
    if df_recom['review_txt'][i] == 'empty':
        # 해당 행삭제
         df_recom.drop(df_recom.index[i])

# %%
# requirements for 감성분석 
from nltk.corpus import wordnet as wn
from nltk.stem import WordNetLemmatizer
from nltk.corpus import sentiwordnet as swn
from nltk import sent_tokenize, word_tokenize, pos_tag

# %%
# 품사 기반 tag로 변환
def penn_to_wn(tag):
    if tag.startswith('J'):
        return wn.ADJ
    elif tag.startswith('N'):
        return wn.NOUN
    elif tag.startswith('R'):
        return wn.ADV
    elif tag.startswith('V'):
        return wn.VERB

# %%
# 총감성지수 > 0 이면 긍정, 아니면 부정 판단
def swn_polarity(text):
    sentiment = 0.0
    tokens_count = 0

    lemmatizer = WordNetLemmatizer()
    raw_sentences = sent_tokenize(str(text))

    for raw_sentence in raw_sentences:
        # nltk 기반의 품사 태깅 문장 추출
        tagged_sentence = pos_tag(word_tokenize(raw_sentence))
        for word, tag in tagged_sentence :
            # wordnet 기반 품사 태깅과 어근 추출
            wn_tag = penn_to_wn(tag)
            if wn_tag not in (wn.NOUN, wn.ADJ, wn.ADJ):
                continue
            lemma = lemmatizer.lemmatize(word, pos = wn_tag)
            if not lemma :
                continue
                
            # 어근을 추출한 단어와 wordnet기반 품사 태깅을 입력하여 synset객체 생성
            synsets = wn.synsets(lemma, pos = wn_tag)
            if not synsets:
                continue
            # sentiwordnet의 감성 단어 분석으로 감성 syntex 추출
            synset = synsets[0]
            swn_synset = swn.senti_synset(synset.name())
            sentiment += (swn_synset.pos_score() - swn_synset.neg_score())
            tokens_count += 1
    if not tokens_count:
        return 0
    # threshold = 0
    if sentiment >= 0:
        return 1
    return 0

# %%
# 데이터에 감성분석 적용 
df_recom['sentiment'] = df_recom['review_txt'].apply(lambda x: swn_polarity(x))
preds = df_recom['sentiment'].values

# %%
#import nltk
#nltk.download('punkt')
#nltk.download('averaged_perceptron_tagger')
#nltk.download('wordnet')
#nltk.download('sentiwordnet')

# %%
df_recom.head()
# Out:
#            name  cate_1       cate_2              cate_3         lon  \
# 0            블룸      양식     정통양식/경양식  음식점 > 술집 > 호프,요리주점  126.960370
# 1  쉬어가는 모퉁이커피한잔  커피점/카페  커피전문점/카페/다방    음식점 > 카페 > 커피전문점  126.953412
# 2          손칼국수      분식    국수/만두/칼국수       음식점 > 한식 > 국수  126.957832
# 3      김가네 중앙대점      분식       라면김밥분식      음식점 > 분식 > 김가네  126.964406
# 4    중앙대학교 학생식당   기타음식업  구내식당/자급식음식점          음식점 > 구내식당  126.953838
#
#          lat  star_point  star_qty  \
# 0  37.507649         4.0       1.0
# 1  37.497226         4.5       5.0
# 2  37.494958         4.1      20.0
# 3  37.507802         1.0       2.0
# 4  37.504798        -1.0       0.0
#
#                                           review_txt  review_qty  \
# 0  블룸 또 갔다믄써~~~ 중대앞에서 칵테일 마시고 싶다면 여기가 ㄱㅊ은듯?? 새벽 1...         2.0
# 1                                              empty         0.0
# 2  사실 후기랄 것이 없다. 자주 가는 곳이고 늘 같은 메뉴. 숭실대 중문 쪽에 아주 ...        28.0
# 3  강식당 보다가 피오가 만든 김치밥 너무 먹구시픈데 집에 김치가 없는 슬픈 자취생이라...         6.0
# 4  중앙대생 점심 메뉴를 추천해드리려고해요 아마 재학생들은 다 알고 있을 310관 지하...         1.0
#
#                             cate_mix  naver_blog_need  sentiment
# 0       양식정통양식 경양식음식점   술집   호프,요리주점              NaN          1
# 1  커피점 카페커피전문점 카페 다방음식점   카페   커피전문점              NaN          1
# 2           분식국수 만두 칼국수음식점   한식   국수              NaN          0
# 3             분식라면김밥분식음식점   분식   김가네              NaN          0
# 4         기타음식업구내식당 자급식음식점음식점   구내식당              NaN          0

# %%
df_recom.to_csv('sentiment_add_df.csv',index = False)
